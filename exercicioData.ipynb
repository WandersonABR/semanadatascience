# %% [markdown]
# # Importando biblioteca e Lendo o arquivo

# %%
import pandas as pd # Importando biblioteca

arquivo = "dataset/IMDB_Top250_Tvshows.csv" # Colocando o arquivo dentro de uma variável
dados = pd.read_csv(arquivo, encoding='latin1') # Colocando o arquivo lido dentro de uma variável pra virar um objeto, encoding pq estava dando erro pra ler
dados # Para mostrar
# Out:
#                               Titile       Year Total_episodes     Age  \
# 0                    1. Breaking Bad  20082013         62 eps      18
# 1                 2. Planet Earth II       2016          6 eps      PG
# 2                    3. Planet Earth       2006         11 eps      PG
# 3                4. Band of Brothers       2001         10 eps      15
# 4                       5. Chernobyl       2019          5 eps      15
# ..                               ...        ...            ...     ...
# 245           246. Your Lie in April  20142015         24 eps      12
# 246                   247. Community  20092015        110 eps      12
# 247  248. Tear Along the Dotted Line       2021          6 eps      15
# 248                249. Chef's Table  20152019         30 eps      15
# 249           250. Sapne Vs Everyone      2023          5 eps  Mature
#
#      Rating Vote_count        Category
# 0       9.5     (2.2M)       TV Series
# ...

# %% [markdown]
# # Lendo as 20 primeiras linhas

# %%
dados.head(20)
# Out:
#                                   Titile       Year Total_episodes Age  \
# 0                        1. Breaking Bad  20082013         62 eps  18
# 1                     2. Planet Earth II       2016          6 eps  PG
# 2                        3. Planet Earth       2006         11 eps  PG
# 3                    4. Band of Brothers       2001         10 eps  15
# 4                           5. Chernobyl       2019          5 eps  15
# 5                            6. The Wire  20022008         60 eps  18
# 6          7. Avatar: The Last Airbender  20052008         62 eps  PG
# 7                      8. Blue Planet II       2017          7 eps   U
# 8                        9. The Sopranos  19992007         86 eps  18
# 9                             10. Cosmos       2014         13 eps  PG
# 10                            11. Cosmos       1980         13 eps   U
# 11                        12. Our Planet  20192023         12 eps   U
# ...

# %% [markdown]
# # Lendo as 20 ultimas linhas

# %%
dados.tail(20)
# Out:
#                                                 Titile       Year  \
# 230                                   231. Letterkenny  20162023
# 231                                    232. Doctor Who  20052022
# 232  233. RurÃ´ni Kenshin: Meiji kenkaku romantan -...       1999
# 233                                   234. The Expanse  20152022
# 234                    235. Extraordinary Attorney Woo       2022
# 235                                      236. Hannibal  20132015
# 236                    237. From the Earth to the Moon       1998
# 237                           238. My Brilliant Friend      2018
# 238                                 239. The Rehearsal      2022
# 239                              240. Wentworth Prison  20132021
# 240                                 241. Avrupa Yakasi  20042009
# 241                                         242. Umbre  20142019
# 242                              243. Alchemy of Souls      2022
# ...
